# %%
# !pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# ...
#      |████████████████████████████████| 7.2 MB 1.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 300 kB 10.2 MB/s eta 0:00:01
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=9c7d7db5a173cd00eaae4f6894cd4b8b8941a8aec661440e67013898d4c0703f
#   Stored in directory: /Users/maksimorluk/Library/Caches/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...
# WARNING: You are using pip version 20.2; however, version 20.2.2 is available.
# You should consider upgrading via the '/Users/maksimorluk/PycharmProjects/Udemy_ml/venv/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
print(np.__version__)
print(pd.__version__)
print(sns.__version__)
# Out:
# 1.19.1
# 1.1.1
# 0.10.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5ec6ef3ca19c> in <module>
#       2 print(pd.__version__)
#       3 print(sns.__version__)
# ----> 4 print(plt.__version__)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
df = pd.read_csv('./Section 2/data/iris.data', header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
col_name = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

# %%
df.columns = col_name

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Iris Data from Seaborn

# %%
iris = sns.load_dataset('iris')

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris_df = iris
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris_df.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# # Visualization

# %%
sns.pairplot(iris_df, hue='species', height=3, aspect=1);

# %%
iris_df.hist();

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=iris_df)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=iris_df)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length', data=iris_df)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width', data=iris_df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
iris_df.boxplot(by='species',figsize=(12,8));

# %%
pd.plotting.scatter_matrix(iris_df, figsize=(12,10));
